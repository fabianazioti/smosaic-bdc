# %%
import os
from smosaic import collection_query, collection_get_data

# %%
path_dir = os.path.abspath("")

# %%
datacube=collection_query(
    collection="S2_L2A-1",
    start_date="2019-06-01",
    end_date="2020-05-31",    
    bbox="-50.5948,-25.0707,-50.0620,-24.6870",
    bands=["B02","B08","SCL"]
)

# %%
collection_get_data(datacube)
