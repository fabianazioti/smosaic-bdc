# %% [markdown]
# # <span style="color:#336699">smosaic</span>
# <hr style="border:2px solid #0077b9;">
#
# <div style="text-align: left;">
#     <a href="https://nbviewer.jupyter.org/github/brazil-data-cube/code-gallery/"><img src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg" align="center"/></a>
# </div>
#
# <br/>
#
# <div style="text-align: center;font-size: 90%;">
#     Gabriel Sansigolo<sup><a href="https://orcid.org/0000-0003-0789-5858"><i class="fab fa-lg fa-orcid" style="color: #a6ce39"></i></a></sup>
#     <br/><br/>
#     Earth Observation and Geoinformatics Division, National Institute for Space Research (INPE)
#     <br/>
#     Avenida dos Astronautas, 1758, Jardim da Granja, São José dos Campos, SP 12227-010, Brazil
#     <br/><br/>
#     Contact: <a href="mailto:gabriel.sansigolo@inpe.br">gabriel.sansigolo@inpe.br</a>
#     <br/><br/>
#     Last Update: Jun 19, 2025
# </div>
#
# <br/>
#
# <div style="text-align: justify;  margin-left: 25%; margin-right: 25%;">
# <b>Abstract.</b> This Jupyter Notebook gives an overview on how to use the smosaic package to create <em>satellite mosaics</em> from big Earth observation data.
# </div>
#
# <br/>
# <div style="text-align: justify;  margin-left: 25%; margin-right: 25%;font-size: 75%; border-style: solid; border-color: #0077b9; border-width: 1px; padding: 5px;">
#     <b>This Jupyter Notebook is a supplement to the following paper:</b>
#     <div style="margin-left: 10px; margin-right: 10px">
#     Sansigolo, G.; Zioti, F; Ferreira, K. R.; Queiroz, G. R.<a href="http://www.google.com" target="_blank">smosaic: a python package for creating satellite mosaics from big Earth observation data
#     </div>
# </div>

# %%
import os
from smosaic import mosaic, open_geojson

# %%
path_dir = os.path.abspath("")

# %%
geometry = open_geojson('brazil.json')

# %%
result = mosaic(
    name="brazil",
    data_dir=os.path.join(path_dir),
    collection="AMZ1-WFI-L4-SR-1", 
    geom=geometry,
    output_dir=os.path.join(path_dir, "output"),   
    mosaic_method="lcf", 
    start_year=2025,
    start_month=1,
    start_day=1,
    duration_months=5, 
    bands=["BAND4"]
)
# Out:
# Downloading... : 100%|██████████| 659/659 [05:16<00:00,  2.08 itens/s]
# Successfully download 659 files to AMZ1-WFI-L4-SR-1
# Building BAND4 mosaic using 49 scenes from the AMZ1-WFI-L4-SR-1
# Building CMASK mosaic using 49 scenes from the AMZ1-WFI-L4-SR-1
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 2 files
# Successfully merged 4 files
# Successfully merged 3 files
# Successfully merged 4 files
# Successfully merged 2 files
# Successfully merged 2 files
# Successfully merged 49 files
# Clipped raster saved to: /Volumes/Extreme SSD/smosaic/output/mosaic-amz1-band4-brazil-5m.tif
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/osgeo/gdal.py:312: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
